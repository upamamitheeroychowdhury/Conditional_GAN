# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import keras

import os

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.10,
                                  
                rotation_range=5,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                #zoom_range=0.2,
                horizontal_flip=True,
                vertical_flip=True,
                fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
#                                    rotation_range=5,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    shear_range=0.2,
#                                    horizontal_flip=True,
#                                    vertical_flip=True,
#                                    fill_mode='nearest',
                                  validation_split = 0.1)

test_datagen  = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=5,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
        #zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest'
                                  )

# %%
#train_dir = f"{os.getcwd()}\\Alzheimer_s Dataset\\train"
test_dir = f"{os.getcwd()}\\Alzheimer_s Dataset\\test"
#test_dir = f"{os.getcwd()}\\generated_image"
train_dir = f"{os.getcwd()}\\Alzheimer_s Dataset_with_gen\\train"

# %%
train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 8)
# Out:
# Found 8210 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = train_dir,
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 8)
# Out:
# Found 911 images belonging to 4 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  batch_size = 8)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
base_model = tf.keras.applications.resnet.ResNet152(input_shape=(224,224,3), 
                   include_top=False)
                   #weights="imagenet")

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.01))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(128,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(256,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(128,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(4,activation='softmax'))

# %%
# Freezing Layers
#for layer in base_model.layers:
    #layer.trainable=False

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 7, 7, 2048)        58370944
#
#  dropout_6 (Dropout)         (None, 7, 7, 2048)        0
#
#  flatten_6 (Flatten)         (None, 100352)            0
#
#  batch_normalization_38 (Bat  (None, 100352)           401408
#  chNormalization)
#
#  dense_38 (Dense)            (None, 64)                6422592
#
#  batch_normalization_39 (Bat  (None, 64)               256
#  chNormalization)
#
#  activation_32 (Activation)  (None, 64)                0
#
#  dense_39 (Dense)            (None, 128)               8320
#
#  batch_normalization_40 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_33 (Activation)  (None, 128)               0
#
#  dense_40 (Dense)            (None, 256)               33024
#
#  batch_normalization_41 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_34 (Activation)  (None, 256)               0
#
#  dense_41 (Dense)            (None, 128)               32896
#
#  batch_normalization_42 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_35 (Activation)  (None, 128)               0
#
#  dense_42 (Dense)            (None, 64)                8256
#
#  batch_normalization_43 (Bat  (None, 64)               256
#  chNormalization)
#
#  activation_36 (Activation)  (None, 64)                0
#
#  dense_43 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 65,280,260
# Trainable params: 64,926,852
# Non-trainable params: 353,408
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
opt = keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy',metrics=METRICS)

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 30 ,
                        verbose = 1)
# Out:
# Epoch 1/30
# 1027/1027 [==============================] - 286s 265ms/step - loss: 1.2156 - accuracy: 0.7528 - precision: 0.5143 - recall: 0.2029 - auc: 0.7090 - f1_score: 0.2829 - val_loss: 1.0350 - val_accuracy: 0.7942 - val_precision: 0.6488 - val_recall: 0.3853 - val_auc: 0.8111 - val_f1_score: 0.4697
# Epoch 2/30
# 1027/1027 [==============================] - 265s 258ms/step - loss: 1.0573 - accuracy: 0.7787 - precision: 0.6147 - recall: 0.3080 - auc: 0.7880 - f1_score: 0.4022 - val_loss: 1.1745 - val_accuracy: 0.7731 - val_precision: 0.7877 - val_recall: 0.1262 - val_auc: 0.6853 - val_f1_score: 0.2052
# Epoch 3/30
# 1027/1027 [==============================] - 265s 258ms/step - loss: 0.9923 - accuracy: 0.7885 - precision: 0.6454 - recall: 0.3417 - auc: 0.8118 - f1_score: 0.4393 - val_loss: 0.9273 - val_accuracy: 0.7942 - val_precision: 0.9215 - val_recall: 0.1932 - val_auc: 0.8323 - val_f1_score: 0.3005
# Epoch 4/30
# 1027/1027 [==============================] - 265s 258ms/step - loss: 0.9684 - accuracy: 0.7914 - precision: 0.6529 - recall: 0.3532 - auc: 0.8205 - f1_score: 0.4507 - val_loss: 47.5122 - val_accuracy: 0.6531 - val_precision: 0.3063 - val_recall: 0.3063 - val_auc: 0.5370 - val_f1_score: 0.3062
# Epoch 5/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.0525 - accuracy: 0.7761 - precision: 0.6092 - recall: 0.2909 - auc: 0.7839 - f1_score: 0.3850 - val_loss: 1.0203 - val_accuracy: 0.7659 - val_precision: 0.5700 - val_recall: 0.2591 - val_auc: 0.7800 - val_f1_score: 0.3458
# Epoch 6/30
# 1027/1027 [==============================] - 266s 258ms/step - loss: 0.9977 - accuracy: 0.7881 - precision: 0.6551 - recall: 0.3220 - auc: 0.8056 - f1_score: 0.4235 - val_loss: 1.1475 - val_accuracy: 0.7569 - val_precision: 0.5337 - val_recall: 0.2173 - val_auc: 0.7264 - val_f1_score: 0.2996
# Epoch 7/30
# 1027/1027 [==============================] - 265s 258ms/step - loss: 0.9493 - accuracy: 0.7963 - precision: 0.6916 - recall: 0.3343 - auc: 0.8232 - f1_score: 0.4431 - val_loss: 0.8682 - val_accuracy: 0.7975 - val_precision: 0.8914 - val_recall: 0.2162 - val_auc: 0.8538 - val_f1_score: 0.3258
# Epoch 8/30
# 1027/1027 [==============================] - 265s 258ms/step - loss: 0.9327 - accuracy: 0.7997 - precision: 0.7024 - recall: 0.3449 - auc: 0.8306 - f1_score: 0.4558 - val_loss: 1.0776 - val_accuracy: 0.7473 - val_precision: 0.4912 - val_recall: 0.3074 - val_auc: 0.7598 - val_f1_score: 0.3663
# Epoch 9/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9053 - accuracy: 0.8034 - precision: 0.7077 - recall: 0.3642 - auc: 0.8412 - f1_score: 0.4732 - val_loss: 0.8577 - val_accuracy: 0.8046 - val_precision: 0.7352 - val_recall: 0.3414 - val_auc: 0.8491 - val_f1_score: 0.4531
# Epoch 10/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.8796 - accuracy: 0.8065 - precision: 0.7163 - recall: 0.3745 - auc: 0.8505 - f1_score: 0.4838 - val_loss: 0.9000 - val_accuracy: 0.7876 - val_precision: 0.6262 - val_recall: 0.3732 - val_auc: 0.8297 - val_f1_score: 0.4549
# Epoch 11/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.8528 - accuracy: 0.8103 - precision: 0.7147 - recall: 0.4016 - auc: 0.8605 - f1_score: 0.5070 - val_loss: 0.7787 - val_accuracy: 0.8104 - val_precision: 0.7148 - val_recall: 0.4018 - val_auc: 0.8818 - val_f1_score: 0.5023
# Epoch 12/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9500 - accuracy: 0.7949 - precision: 0.6628 - recall: 0.3658 - auc: 0.8299 - f1_score: 0.4619 - val_loss: 0.9175 - val_accuracy: 0.7977 - val_precision: 0.7186 - val_recall: 0.3139 - val_auc: 0.8271 - val_f1_score: 0.4227
# Epoch 13/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.0637 - accuracy: 0.7769 - precision: 0.6240 - recall: 0.2703 - auc: 0.7831 - f1_score: 0.3660 - val_loss: 1.0657 - val_accuracy: 0.7750 - val_precision: 0.6409 - val_recall: 0.2272 - val_auc: 0.7697 - val_f1_score: 0.3153
# Epoch 14/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.1017 - accuracy: 0.7664 - precision: 0.5815 - recall: 0.2333 - auc: 0.7617 - f1_score: 0.3261 - val_loss: 1.0559 - val_accuracy: 0.7722 - val_precision: 0.7516 - val_recall: 0.1328 - val_auc: 0.7413 - val_f1_score: 0.2084
# Epoch 15/30
# 1027/1027 [==============================] - 265s 258ms/step - loss: 1.0643 - accuracy: 0.7776 - precision: 0.6418 - recall: 0.2503 - auc: 0.7752 - f1_score: 0.3516 - val_loss: 227.1731 - val_accuracy: 0.6959 - val_precision: 0.3919 - val_recall: 0.3919 - val_auc: 0.5942 - val_f1_score: 0.3919
# Epoch 16/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.1155 - accuracy: 0.7747 - precision: 0.6356 - recall: 0.2315 - auc: 0.7547 - f1_score: 0.3332 - val_loss: 0.9561 - val_accuracy: 0.7810 - val_precision: 0.8645 - val_recall: 0.1471 - val_auc: 0.7846 - val_f1_score: 0.2330
# Epoch 17/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.0172 - accuracy: 0.7884 - precision: 0.6984 - recall: 0.2705 - auc: 0.7945 - f1_score: 0.3822 - val_loss: 0.9119 - val_accuracy: 0.7928 - val_precision: 0.8171 - val_recall: 0.2206 - val_auc: 0.8319 - val_f1_score: 0.3272
# Epoch 18/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9748 - accuracy: 0.7956 - precision: 0.7229 - recall: 0.2959 - auc: 0.8107 - f1_score: 0.4130 - val_loss: 1.0253 - val_accuracy: 0.7816 - val_precision: 0.8571 - val_recall: 0.1515 - val_auc: 0.7668 - val_f1_score: 0.2355
# Epoch 19/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9567 - accuracy: 0.7986 - precision: 0.7517 - recall: 0.2905 - auc: 0.8185 - f1_score: 0.4099 - val_loss: 0.9474 - val_accuracy: 0.7857 - val_precision: 0.6601 - val_recall: 0.2942 - val_auc: 0.8093 - val_f1_score: 0.3884
# Epoch 20/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9671 - accuracy: 0.7956 - precision: 0.7282 - recall: 0.2911 - auc: 0.8151 - f1_score: 0.4088 - val_loss: 0.9386 - val_accuracy: 0.7870 - val_precision: 0.9530 - val_recall: 0.1559 - val_auc: 0.8130 - val_f1_score: 0.2446
# Epoch 21/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9457 - accuracy: 0.7981 - precision: 0.7451 - recall: 0.2923 - auc: 0.8208 - f1_score: 0.4116 - val_loss: 0.9621 - val_accuracy: 0.7838 - val_precision: 0.9843 - val_recall: 0.1372 - val_auc: 0.7923 - val_f1_score: 0.2191
# Epoch 22/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9382 - accuracy: 0.8002 - precision: 0.7606 - recall: 0.2929 - auc: 0.8246 - f1_score: 0.4141 - val_loss: 0.9614 - val_accuracy: 0.7813 - val_precision: 0.9831 - val_recall: 0.1273 - val_auc: 0.7964 - val_f1_score: 0.2096
# Epoch 23/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9114 - accuracy: 0.8036 - precision: 0.7704 - recall: 0.3054 - auc: 0.8337 - f1_score: 0.4291 - val_loss: 0.9835 - val_accuracy: 0.7805 - val_precision: 0.9826 - val_recall: 0.1240 - val_auc: 0.7657 - val_f1_score: 0.2041
# Epoch 24/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9918 - accuracy: 0.7961 - precision: 0.7640 - recall: 0.2670 - auc: 0.8067 - f1_score: 0.3878 - val_loss: 0.9982 - val_accuracy: 0.7802 - val_precision: 0.9911 - val_recall: 0.1218 - val_auc: 0.7459 - val_f1_score: 0.1978
# Epoch 25/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 0.9437 - accuracy: 0.7999 - precision: 0.7556 - recall: 0.2952 - auc: 0.8210 - f1_score: 0.4164 - val_loss: 0.9567 - val_accuracy: 0.7835 - val_precision: 0.9919 - val_recall: 0.1350 - val_auc: 0.7947 - val_f1_score: 0.2154
# Epoch 26/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.0750 - accuracy: 0.7863 - precision: 0.7305 - recall: 0.2301 - auc: 0.7749 - f1_score: 0.3376 - val_loss: 1.1007 - val_accuracy: 0.7783 - val_precision: 0.9905 - val_recall: 0.1142 - val_auc: 0.7808 - val_f1_score: 0.1862
# Epoch 27/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.0876 - accuracy: 0.7800 - precision: 0.6907 - recall: 0.2173 - auc: 0.7680 - f1_score: 0.3250 - val_loss: 0.9858 - val_accuracy: 0.7788 - val_precision: 0.9907 - val_recall: 0.1164 - val_auc: 0.7970 - val_f1_score: 0.1914
# Epoch 28/30
# 1027/1027 [==============================] - 266s 259ms/step - loss: 1.0197 - accuracy: 0.7887 - precision: 0.7280 - recall: 0.2474 - auc: 0.7941 - f1_score: 0.3623 - val_loss: 0.9561 - val_accuracy: 0.7832 - val_precision: 0.9618 - val_recall: 0.1383 - val_auc: 0.7970 - val_f1_score: 0.2229
# Epoch 29/30
# 1027/1027 [==============================] - 263s 256ms/step - loss: 0.9836 - accuracy: 0.7952 - precision: 0.7532 - recall: 0.2687 - auc: 0.8068 - f1_score: 0.3898 - val_loss: 2.7657 - val_accuracy: 0.5587 - val_precision: 0.1158 - val_recall: 0.1153 - val_auc: 0.4603 - val_f1_score: 0.1158
# Epoch 30/30
# 1027/1027 [==============================] - 263s 257ms/step - loss: 0.9968 - accuracy: 0.7937 - precision: 0.7366 - recall: 0.2719 - auc: 0.8053 - f1_score: 0.3907 - val_loss: 1.0699 - val_accuracy: 0.7802 - val_precision: 0.9365 - val_recall: 0.1295 - val_auc: 0.7165 - val_f1_score: 0.2122

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate_generator(test_dataset)
# Out:
# C:\Users\Guest-ccc\AppData\Local\Temp\ipykernel_8324\39297891.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scores = model.evaluate_generator(test_dataset)

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.7910476922988892
# Precision =  0.6779661178588867
# Recall =  0.3127443194389343
# AUC =  0.8095616102218628
# F1_score =  0.41653114557266235
